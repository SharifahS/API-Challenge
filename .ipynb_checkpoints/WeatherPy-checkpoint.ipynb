# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.
#
#
# #Analysis
#
# 1. Temperature increases as you move closer to the equator.
# 2. Windspeed is very steady around the world.
# 3. Latitude doesn't really affect cloudiness and humidity.

# %%
# Dependencies and Setup
import time
import requests
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy
from pprint import pprint
from scipy.stats import linregress
from api_keys import weather_api_key

# Output File (CSV)
output_data_file = "output/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
long_range = (-180, 180)

api_key = '2c3350772f4baf0077349d60ffb2855d'

# %% [markdown]
# ## Generate Cities List

# %%
# create lists
lat_lngs = []
cities = []

# generate latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# identify closest city to coordinates
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # add unique cities
    if city not in cities:
        cities.append(city)

# Print the city count
print(len(cities))
# Out:
# 620

# %%
city_test = ['Toronto', 'Paris', 'Corona Virus', 'Bern', 'Vienna', 'John', 'Dunsk', 'San Francisco', 
             'Jamaica','Rio', 'London', 'Tokyo']

# url for api
base_url = f"http://api.openweathermap.org/data/2.5/weather?&appid={api_key}&q="

#set value and count for city
city_test_list = []
city_number=1

#Print Log
for i in city_test:
    city_url = base_url + i
    response_test= requests.get(city_url).json()

    try:
        city_test_list.append(response_test['name'])
        print(f"Processing record {city_number} of|{i}")
        city_number +=1
        
    except:
        # Append null values
        print(f"City not found.  Skipping..")
        pass
# Out:
# Processing record 1 of|Toronto
# Processing record 2 of|Paris
# City not found.  Skipping..
# Processing record 3 of|Bern
# Processing record 4 of|Vienna
# Processing record 5 of|John
# City not found.  Skipping..
# Processing record 6 of|San Francisco
# Processing record 7 of|Jamaica
# Processing record 8 of|Rio
# Processing record 9 of|London
# Processing record 10 of|Tokyo

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
### Perform API Calls
#Weather check on each city
#Perform quick test
#Run test with sample cities

# Create empty lists for dataframe to plot data
cityname = []
temperature_max = []
cloudiness =[]
humidity=[]
windspeed=[]
latitude=[]
longitude=[]
date=[]
country = []

print("Start Retrieval")

# value for record and set count
record = 1
set_number = 1

# Loop through cities to get info
# Print log of all cities found



for city in cities:
    weather_url = base_url + city
    response= requests.get(weather_url + "&units=imperial").json()

    try:
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        latitude.append(response['coord']['lat'])
        longitude.append(response['coord']['lon'])
        temperature_max.append(response['main']['temp_max'])
        windspeed.append(response['wind']['speed'])
        print(f"Processing record {record} of set {set_number}|{city}")
        
        # record and set count
        if record > 49:
            record = 1
            set_number += 1
            cityname.append(city)
        else:
            record += 1
            cityname.append(city)
    except:
        print(f"City not found.  Skipping..")
        pass
print("-----------------------------")
print("Data Retrieval Complete") 
print("-----------------------------")
# Out:
# Start Retrieval
# Processing record 1 of set 1|khatanga
# Processing record 2 of set 1|rikitea
# Processing record 3 of set 1|stokmarknes
# Processing record 4 of set 1|carnarvon
# Processing record 5 of set 1|bambous virieux
# Processing record 6 of set 1|kodiak
# City not found.  Skipping..
# Processing record 7 of set 1|iqaluit
# Processing record 8 of set 1|gangapur
# Processing record 9 of set 1|cairns
# Processing record 10 of set 1|saint-francois
# Processing record 11 of set 1|new norfolk
# City not found.  Skipping..
# Processing record 12 of set 1|chicama
# City not found.  Skipping..
# Processing record 13 of set 1|georgetown
# Processing record 14 of set 1|san pedro
# Processing record 15 of set 1|promyshlennovskiy
# Processing record 16 of set 1|hobart
# Processing record 17 of set 1|bikin
# Processing record 18 of set 1|ushuaia
# Processing record 19 of set 1|itarema
# Processing record 20 of set 1|san carlos
# Processing record 21 of set 1|ancud
# Processing record 22 of set 1|grand gaube
# Processing record 23 of set 1|punta arenas
# Processing record 24 of set 1|belize
# Processing record 25 of set 1|sungaipenuh
# Processing record 26 of set 1|mataura
# Processing record 27 of set 1|bredasdorp
# Processing record 28 of set 1|arraial do cabo
# Processing record 29 of set 1|teguise
# Processing record 30 of set 1|hasaki
# Processing record 31 of set 1|dombarovskiy
# Processing record 32 of set 1|nikolskoye
# Processing record 33 of set 1|cabo san lucas
# Processing record 34 of set 1|wilkie
# Processing record 35 of set 1|saint-philippe
# Processing record 36 of set 1|joshimath
# Processing record 37 of set 1|poum
# Processing record 38 of set 1|lubao
# Processing record 39 of set 1|yellowknife
# Processing record 40 of set 1|lebu
# Processing record 41 of set 1|sao jose da coroa grande
# Processing record 42 of set 1|magnor
# City not found.  Skipping..
# Processing record 43 of set 1|roald
# Processing record 44 of set 1|bethel
# Processing record 45 of set 1|castro
# Processing record 46 of set 1|thompson
# Processing record 47 of set 1|los andes
# Processing record 48 of set 1|bengkulu
# City not found.  Skipping..
# Processing record 49 of set 1|atuona
# Processing record 50 of set 1|jamestown
# City not found.  Skipping..
# Processing record 1 of set 2|namibe
# City not found.  Skipping..
# Processing record 2 of set 2|kavaratti
# Processing record 3 of set 2|williston
# Processing record 4 of set 2|conceicao do araguaia
# Processing record 5 of set 2|tuktoyaktuk
# Processing record 6 of set 2|kloulklubed
# Processing record 7 of set 2|chokurdakh
# Processing record 8 of set 2|chumikan
# Processing record 9 of set 2|deputatskiy
# Processing record 10 of set 2|high rock
# Processing record 11 of set 2|albany
# Processing record 12 of set 2|djambala
# Processing record 13 of set 2|vaini
# Processing record 14 of set 2|ukiah
# Processing record 15 of set 2|vester hassing
# Processing record 16 of set 2|bluff
# Processing record 17 of set 2|yatou
# Processing record 18 of set 2|barrow
# City not found.  Skipping..
# Processing record 19 of set 2|chuy
# Processing record 20 of set 2|bogorodskoye
# Processing record 21 of set 2|soyo
# Processing record 22 of set 2|saint-augustin
# Processing record 23 of set 2|tiksi
# Processing record 24 of set 2|sept-iles
# Processing record 25 of set 2|busselton
# Processing record 26 of set 2|wajid
# Processing record 27 of set 2|aden
# City not found.  Skipping..
# Processing record 28 of set 2|opuwo
# Processing record 29 of set 2|klaksvik
# Processing record 30 of set 2|anzio
# Processing record 31 of set 2|jalu
# Processing record 32 of set 2|sao joao da barra
# Processing record 33 of set 2|makakilo city
# Processing record 34 of set 2|port elizabeth
# Processing record 35 of set 2|faanui
# Processing record 36 of set 2|kavieng
# Processing record 37 of set 2|sao filipe
# Processing record 38 of set 2|tual
# Processing record 39 of set 2|butaritari
# Processing record 40 of set 2|santa maria
# Processing record 41 of set 2|whitecourt
# Processing record 42 of set 2|enshi
# Processing record 43 of set 2|petropavlovsk-kamchatskiy
# Processing record 44 of set 2|ilulissat
# Processing record 45 of set 2|saskylakh
# Processing record 46 of set 2|cape town
# Processing record 47 of set 2|krasnopavlivka
# Processing record 48 of set 2|luanda
# Processing record 49 of set 2|noumea
# Processing record 50 of set 2|acarau
# City not found.  Skipping..
# Processing record 1 of set 3|kaitangata
# Processing record 2 of set 3|shanhetun
# Processing record 3 of set 3|saint-pierre
# Processing record 4 of set 3|naustdal
# Processing record 5 of set 3|rincon
# Processing record 6 of set 3|steinbach
# Processing record 7 of set 3|umm kaddadah
# Processing record 8 of set 3|isangel
# Processing record 9 of set 3|retz
# Processing record 10 of set 3|mar del plata
# Processing record 11 of set 3|dikson
# Processing record 12 of set 3|port-cartier
# Processing record 13 of set 3|ulladulla
# Processing record 14 of set 3|moose factory
# Processing record 15 of set 3|talcahuano
# Processing record 16 of set 3|paamiut
# Processing record 17 of set 3|broome
# Processing record 18 of set 3|taitung
# City not found.  Skipping..
# Processing record 19 of set 3|tigil
# Processing record 20 of set 3|longyearbyen
# Processing record 21 of set 3|baykit
# Processing record 22 of set 3|severo-kurilsk
# Processing record 23 of set 3|mineiros
# Processing record 24 of set 3|atherton
# Processing record 25 of set 3|boyolangu
# Processing record 26 of set 3|plouzane
# Processing record 27 of set 3|norman wells
# Processing record 28 of set 3|fukue
# Processing record 29 of set 3|kapaa
# Processing record 30 of set 3|mahebourg
# Processing record 31 of set 3|parkes
# Processing record 32 of set 3|hermanus
# Processing record 33 of set 3|marsa matruh
# Processing record 34 of set 3|tilichiki
# Processing record 35 of set 3|zverinogolovskoye
# Processing record 36 of set 3|ribeira grande
# Processing record 37 of set 3|heidelberg
# Processing record 38 of set 3|anadyr
# Processing record 39 of set 3|souillac
# Processing record 40 of set 3|dublin
# Processing record 41 of set 3|hithadhoo
# Processing record 42 of set 3|hilo
# Processing record 43 of set 3|sampit
# City not found.  Skipping..
# Processing record 44 of set 3|nome
# Processing record 45 of set 3|victoria
# Processing record 46 of set 3|alpena
# Processing record 47 of set 3|labuhan
# Processing record 48 of set 3|hobyo
# Processing record 49 of set 3|lulea
# Processing record 50 of set 3|rundu
# Processing record 1 of set 4|abu dhabi
# City not found.  Skipping..
# Processing record 2 of set 4|ponta do sol
# Processing record 3 of set 4|armidale
# Processing record 4 of set 4|sosenskiy
# Processing record 5 of set 4|hamilton
# Processing record 6 of set 4|lensk
# Processing record 7 of set 4|hualmay
# Processing record 8 of set 4|arawa
# Processing record 9 of set 4|hervey bay
# Processing record 10 of set 4|provideniya
# Processing record 11 of set 4|vilyuysk
# City not found.  Skipping..
# City not found.  Skipping..
# Processing record 12 of set 4|apatou
# Processing record 13 of set 4|eyl
# Processing record 14 of set 4|canutama
# Processing record 15 of set 4|upernavik
# Processing record 16 of set 4|port alfred
# Processing record 17 of set 4|esperance
# Processing record 18 of set 4|flinders
# Processing record 19 of set 4|tisul
# City not found.  Skipping..
# Processing record 20 of set 4|lakes entrance
# Processing record 21 of set 4|togur
# Processing record 22 of set 4|ercis
# Processing record 23 of set 4|mayo
# Processing record 24 of set 4|beloha
# Processing record 25 of set 4|springfield
# Processing record 26 of set 4|cherskiy
# Processing record 27 of set 4|hollins
# Processing record 28 of set 4|luderitz
# Processing record 29 of set 4|cidreira
# Processing record 30 of set 4|laguna
# Processing record 31 of set 4|coihueco
# Processing record 32 of set 4|vanavara
# City not found.  Skipping..
# Processing record 33 of set 4|tezu
# Processing record 34 of set 4|myitkyina
# City not found.  Skipping..
# City not found.  Skipping..
# Processing record 35 of set 4|valparaiso
# Processing record 36 of set 4|anloga
# Processing record 37 of set 4|fairbanks
# Processing record 38 of set 4|mattru
# Processing record 39 of set 4|balabac
# Processing record 40 of set 4|avera
# Processing record 41 of set 4|berlevag
# Processing record 42 of set 4|monrovia
# Processing record 43 of set 4|derzhavinsk
# Processing record 44 of set 4|haines junction
# Processing record 45 of set 4|romodanovo
# Processing record 46 of set 4|hambantota
# Processing record 47 of set 4|ahipara
# Processing record 48 of set 4|piacabucu
# Processing record 49 of set 4|kyshtovka
# Processing record 50 of set 4|lavrentiya
# Processing record 1 of set 5|bisho
# Processing record 2 of set 5|ngunguru
# Processing record 3 of set 5|san quintin
# Processing record 4 of set 5|byron bay
# Processing record 5 of set 5|moroni
# Processing record 6 of set 5|vostok
# Processing record 7 of set 5|cafarnaum
# Processing record 8 of set 5|vagur
# Processing record 9 of set 5|sal rei
# Processing record 10 of set 5|sibolga
# Processing record 11 of set 5|mishkino
# Processing record 12 of set 5|talnakh
# Processing record 13 of set 5|sitka
# Processing record 14 of set 5|yuzhno-sukhokumsk
# Processing record 15 of set 5|kearney
# Processing record 16 of set 5|cheyenne
# Processing record 17 of set 5|saint george
# Processing record 18 of set 5|olinda
# City not found.  Skipping..
# Processing record 19 of set 5|taoudenni
# Processing record 20 of set 5|beringovskiy
# Processing record 21 of set 5|challans
# Processing record 22 of set 5|narsaq
# Processing record 23 of set 5|qaanaaq
# Processing record 24 of set 5|carutapera
# Processing record 25 of set 5|caceres
# Processing record 26 of set 5|zyryanka
# Processing record 27 of set 5|kempsey
# Processing record 28 of set 5|san felipe
# Processing record 29 of set 5|auki
# Processing record 30 of set 5|beyneu
# Processing record 31 of set 5|leeton
# Processing record 32 of set 5|chon daen
# Processing record 33 of set 5|geraldton
# Processing record 34 of set 5|clovis
# Processing record 35 of set 5|tayoltita
# Processing record 36 of set 5|folldal
# Processing record 37 of set 5|tasiilaq
# Processing record 38 of set 5|mehamn
# City not found.  Skipping..
# Processing record 39 of set 5|tuatapere
# Processing record 40 of set 5|kirkland lake
# Processing record 41 of set 5|erdenet
# Processing record 42 of set 5|cordele
# Processing record 43 of set 5|kununurra
# Processing record 44 of set 5|kerewan
# Processing record 45 of set 5|merauke
# Processing record 46 of set 5|iquitos
# Processing record 47 of set 5|mithi
# Processing record 48 of set 5|collie
# Processing record 49 of set 5|qaqortoq
# Processing record 50 of set 5|kysyl-syr
# Processing record 1 of set 6|inirida
# Processing record 2 of set 6|qandala
# Processing record 3 of set 6|karakol
# Processing record 4 of set 6|centralia
# Processing record 5 of set 6|zhangye
# City not found.  Skipping..
# Processing record 6 of set 6|popondetta
# City not found.  Skipping..
# Processing record 7 of set 6|brae
# Processing record 8 of set 6|maridi
# Processing record 9 of set 6|roma
# Processing record 10 of set 6|damphu
# Processing record 11 of set 6|ondarroa
# Processing record 12 of set 6|ostuacan
# Processing record 13 of set 6|husavik
# Processing record 14 of set 6|tarko-sale
# Processing record 15 of set 6|clyde river
# Processing record 16 of set 6|mantua
# Processing record 17 of set 6|biak
# Processing record 18 of set 6|yerbogachen
# Processing record 19 of set 6|lompoc
# Processing record 20 of set 6|nyaunglebin
# Processing record 21 of set 6|buraydah
# Processing record 22 of set 6|katsuura
# Processing record 23 of set 6|mizdah
# Processing record 24 of set 6|salcininkai
# Processing record 25 of set 6|richards bay
# Processing record 26 of set 6|katobu
# Processing record 27 of set 6|vardo
# Processing record 28 of set 6|marabba
# City not found.  Skipping..
# Processing record 29 of set 6|moerai
# Processing record 30 of set 6|airai
# Processing record 31 of set 6|bonavista
# Processing record 32 of set 6|east london
# City not found.  Skipping..
# Processing record 33 of set 6|wewak
# Processing record 34 of set 6|ambilobe
# Processing record 35 of set 6|flin flon
# Processing record 36 of set 6|komsomolskiy
# Processing record 37 of set 6|comodoro rivadavia
# City not found.  Skipping..
# City not found.  Skipping..
# Processing record 38 of set 6|arman
# Processing record 39 of set 6|mae hong son
# Processing record 40 of set 6|sfantu gheorghe
# Processing record 41 of set 6|coihaique
# Processing record 42 of set 6|longkou
# Processing record 43 of set 6|biltine
# Processing record 44 of set 6|constitucion
# Processing record 45 of set 6|waddan
# Processing record 46 of set 6|puerto ayora
# Processing record 47 of set 6|kabarnet
# Processing record 48 of set 6|kuytun
# Processing record 49 of set 6|tibasosa
# Processing record 50 of set 6|udachnyy
# City not found.  Skipping..
# Processing record 1 of set 7|andrelandia
# Processing record 2 of set 7|smithers
# Processing record 3 of set 7|yuxia
# Processing record 4 of set 7|alofi
# Processing record 5 of set 7|kaohsiung
# Processing record 6 of set 7|touros
# Processing record 7 of set 7|krasnoselkup
# Processing record 8 of set 7|chatellerault
# Processing record 9 of set 7|acapulco
# Processing record 10 of set 7|port lincoln
# Processing record 11 of set 7|porto seguro
# Processing record 12 of set 7|chupa
# Processing record 13 of set 7|los llanos de aridane
# City not found.  Skipping..
# Processing record 14 of set 7|okhotsk
# Processing record 15 of set 7|huarmey
# Processing record 16 of set 7|pemangkat
# Processing record 17 of set 7|port augusta
# Processing record 18 of set 7|aquiraz
# Processing record 19 of set 7|hue
# Processing record 20 of set 7|punta alta
# Processing record 21 of set 7|loding
# Processing record 22 of set 7|rudsar
# Processing record 23 of set 7|kaniama
# Processing record 24 of set 7|lincoln
# Processing record 25 of set 7|port blair
# Processing record 26 of set 7|laurel
# Processing record 27 of set 7|bedford
# City not found.  Skipping..
# Processing record 28 of set 7|kirovsk
# Processing record 29 of set 7|shingu
# Processing record 30 of set 7|webuye
# Processing record 31 of set 7|torbay
# Processing record 32 of set 7|northam
# Processing record 33 of set 7|boralday
# Processing record 34 of set 7|aripuana
# City not found.  Skipping..
# Processing record 35 of set 7|juneau
# Processing record 36 of set 7|rochegda
# Processing record 37 of set 7|vila velha
# Processing record 38 of set 7|lorengau
# Processing record 39 of set 7|adrar
# Processing record 40 of set 7|otuzco
# Processing record 41 of set 7|guarapari
# Processing record 42 of set 7|hofn
# Processing record 43 of set 7|usinsk
# Processing record 44 of set 7|grindavik
# Processing record 45 of set 7|avarua
# Processing record 46 of set 7|mandalgovi
# Processing record 47 of set 7|ola
# Processing record 48 of set 7|palmer
# Processing record 49 of set 7|solnechnyy
# Processing record 50 of set 7|sao borja
# Processing record 1 of set 8|lazaro cardenas
# Processing record 2 of set 8|george town
# Processing record 3 of set 8|amapa
# Processing record 4 of set 8|chokwe
# Processing record 5 of set 8|kashi
# Processing record 6 of set 8|santa isabel do rio negro
# Processing record 7 of set 8|ballina
# Processing record 8 of set 8|el cairo
# Processing record 9 of set 8|chernyshevskiy
# Processing record 10 of set 8|karratha
# Processing record 11 of set 8|chimoio
# Processing record 12 of set 8|omagh
# Processing record 13 of set 8|portland
# Processing record 14 of set 8|paignton
# Processing record 15 of set 8|cabedelo
# City not found.  Skipping..
# Processing record 16 of set 8|banjar
# Processing record 17 of set 8|smirnykh
# Processing record 18 of set 8|pangian
# Processing record 19 of set 8|reconquista
# Processing record 20 of set 8|westport
# Processing record 21 of set 8|lasa
# Processing record 22 of set 8|kayes
# Processing record 23 of set 8|tabuk
# Processing record 24 of set 8|sechura
# Processing record 25 of set 8|sisophon
# Processing record 26 of set 8|shumskiy
# Processing record 27 of set 8|mezen
# Processing record 28 of set 8|sao felix do xingu
# Processing record 29 of set 8|bonthe
# Processing record 30 of set 8|ouadda
# Processing record 31 of set 8|andrushivka
# Processing record 32 of set 8|dunoon
# Processing record 33 of set 8|pitimbu
# City not found.  Skipping..
# Processing record 34 of set 8|birjand
# Processing record 35 of set 8|rawson
# Processing record 36 of set 8|wana
# Processing record 37 of set 8|gunjur
# Processing record 38 of set 8|shimoda
# Processing record 39 of set 8|kaina
# Processing record 40 of set 8|dayong
# Processing record 41 of set 8|epe
# Processing record 42 of set 8|tricase
# Processing record 43 of set 8|zhuhai
# Processing record 44 of set 8|leningradskiy
# Processing record 45 of set 8|petropavlovka
# Processing record 46 of set 8|batagay
# Processing record 47 of set 8|phan thiet
# Processing record 48 of set 8|vanimo
# Processing record 49 of set 8|celestun
# City not found.  Skipping..
# Processing record 50 of set 8|san patricio
# Processing record 1 of set 9|kaarina
# Processing record 2 of set 9|iquique
# Processing record 3 of set 9|srednekolymsk
# Processing record 4 of set 9|maragogi
# Processing record 5 of set 9|viedma
# City not found.  Skipping..
# Processing record 6 of set 9|kendari
# Processing record 7 of set 9|alizai
# Processing record 8 of set 9|bubaque
# Processing record 9 of set 9|zhigansk
# Processing record 10 of set 9|korem
# Processing record 11 of set 9|tura
# Processing record 12 of set 9|thinadhoo
# Processing record 13 of set 9|bathsheba
# Processing record 14 of set 9|evensk
# Processing record 15 of set 9|san cristobal
# Processing record 16 of set 9|yasnyy
# Processing record 17 of set 9|nusaybin
# Processing record 18 of set 9|bocaiuva
# Processing record 19 of set 9|maryville
# Processing record 20 of set 9|necochea
# Processing record 21 of set 9|la ronge
# Processing record 22 of set 9|cozumel
# Processing record 23 of set 9|loiza
# Processing record 24 of set 9|ust-omchug
# Processing record 25 of set 9|gagnoa
# Processing record 26 of set 9|marawi
# Processing record 27 of set 9|alamogordo
# Processing record 28 of set 9|ketchikan
# City not found.  Skipping..
# Processing record 29 of set 9|sarangani
# Processing record 30 of set 9|asfi
# Processing record 31 of set 9|sadiqabad
# City not found.  Skipping..
# Processing record 32 of set 9|kalaiya
# Processing record 33 of set 9|meadow lake
# Processing record 34 of set 9|mount gambier
# Processing record 35 of set 9|marsaxlokk
# Processing record 36 of set 9|nanortalik
# City not found.  Skipping..
# Processing record 37 of set 9|pangai
# Processing record 38 of set 9|ouargaye
# Processing record 39 of set 9|bilibino
# City not found.  Skipping..
# City not found.  Skipping..
# Processing record 40 of set 9|broken hill
# Processing record 41 of set 9|aykino
# Processing record 42 of set 9|mpraeso
# Processing record 43 of set 9|pacific grove
# Processing record 44 of set 9|maniitsoq
# Processing record 45 of set 9|sladkovo
# Processing record 46 of set 9|escada
# Processing record 47 of set 9|port hedland
# Processing record 48 of set 9|dicabisagan
# Processing record 49 of set 9|oranjemund
# Processing record 50 of set 9|te anau
# Processing record 1 of set 10|takoradi
# Processing record 2 of set 10|corner brook
# Processing record 3 of set 10|port-gentil
# Processing record 4 of set 10|boueni
# Processing record 5 of set 10|morondava
# Processing record 6 of set 10|coahuayana
# Processing record 7 of set 10|olivenza
# Processing record 8 of set 10|kahului
# Processing record 9 of set 10|port hardy
# Processing record 10 of set 10|kirakira
# Processing record 11 of set 10|arlit
# Processing record 12 of set 10|gerash
# Processing record 13 of set 10|tres arroyos
# Processing record 14 of set 10|nauta
# Processing record 15 of set 10|henties bay
# Processing record 16 of set 10|sola
# Processing record 17 of set 10|mbaiki
# Processing record 18 of set 10|seoul
# Processing record 19 of set 10|fortuna
# Processing record 20 of set 10|yar-sale
# Processing record 21 of set 10|pisco
# Processing record 22 of set 10|esna
# Processing record 23 of set 10|kargasok
# Processing record 24 of set 10|kokopo
# Processing record 25 of set 10|calvinia
# Processing record 26 of set 10|tukums
# Processing record 27 of set 10|aginskoye
# Processing record 28 of set 10|aklavik
# Processing record 29 of set 10|boddam
# Processing record 30 of set 10|dongsheng
# Processing record 31 of set 10|astaneh-ye ashrafiyeh
# Processing record 32 of set 10|filingue
# Processing record 33 of set 10|burnie
# Processing record 34 of set 10|ilebo
# Processing record 35 of set 10|puerto plata
# Processing record 36 of set 10|havre-saint-pierre
# Processing record 37 of set 10|inhumas
# Processing record 38 of set 10|vila franca do campo
# Processing record 39 of set 10|boende
# Processing record 40 of set 10|pafos
# Processing record 41 of set 10|churapcha
# Processing record 42 of set 10|tshikapa
# Processing record 43 of set 10|alta floresta
# Processing record 44 of set 10|bilma
# Processing record 45 of set 10|hashtrud
# Processing record 46 of set 10|gucheng
# Processing record 47 of set 10|college
# Processing record 48 of set 10|sarandi
# Processing record 49 of set 10|weligama
# Processing record 50 of set 10|shahrud
# Processing record 1 of set 11|tautira
# Processing record 2 of set 11|sumbe
# Processing record 3 of set 11|vestmannaeyjar
# Processing record 4 of set 11|yinchuan
# Processing record 5 of set 11|kalmunai
# Processing record 6 of set 11|inhambane
# Processing record 7 of set 11|magistralnyy
# Processing record 8 of set 11|olden
# Processing record 9 of set 11|pramanta
# Processing record 10 of set 11|springbok
# Processing record 11 of set 11|beni suef
# Processing record 12 of set 11|liverpool
# Processing record 13 of set 11|plettenberg bay
# Processing record 14 of set 11|mackay
# Processing record 15 of set 11|demerval lobao
# Processing record 16 of set 11|margate
# Processing record 17 of set 11|nelson bay
# Processing record 18 of set 11|phirangipuram
# Processing record 19 of set 11|yarkovo
# Processing record 20 of set 11|port angeles
# Processing record 21 of set 11|jian
# Processing record 22 of set 11|bosaso
# Processing record 23 of set 11|presidencia roque saenz pena
# Processing record 24 of set 11|samarai
# Processing record 25 of set 11|romny
# City not found.  Skipping..
# Processing record 26 of set 11|cockburn town
# Processing record 27 of set 11|nizhniy odes
# City not found.  Skipping..
# Processing record 28 of set 11|tiznit
# Processing record 29 of set 11|orocue
# Processing record 30 of set 11|dwarka
# Processing record 31 of set 11|kuching
# Processing record 32 of set 11|jalpan
# Processing record 33 of set 11|faya
# Processing record 34 of set 11|malacacheta
# Processing record 35 of set 11|salym
# Processing record 36 of set 11|riberalta
# Processing record 37 of set 11|kruisfontein
# Processing record 38 of set 11|cayenne
# Processing record 39 of set 11|ginir
# Processing record 40 of set 11|nan
# Processing record 41 of set 11|nuevo casas grandes
# City not found.  Skipping..
# Processing record 42 of set 11|alyangula
# Processing record 43 of set 11|durant
# Processing record 44 of set 11|olafsvik
# Processing record 45 of set 11|manaure
# Processing record 46 of set 11|nouadhibou
# Processing record 47 of set 11|bud
# Processing record 48 of set 11|port moresby
# Processing record 49 of set 11|nuuk
# Processing record 50 of set 11|shalazhi
# Processing record 1 of set 12|saldanha
# Processing record 2 of set 12|waingapu
# Processing record 3 of set 12|raduzhnyy
# Processing record 4 of set 12|kasongo
# Processing record 5 of set 12|batemans bay
# City not found.  Skipping..
# Processing record 6 of set 12|tubuala
# Processing record 7 of set 12|la rioja
# Processing record 8 of set 12|ugoofaaru
# Processing record 9 of set 12|jacareacanga
# Processing record 10 of set 12|prince george
# Processing record 11 of set 12|gizo
# Processing record 12 of set 12|moron
# Processing record 13 of set 12|maldonado
# Processing record 14 of set 12|nizwa
# Processing record 15 of set 12|kunming
# Processing record 16 of set 12|santa cruz
# Processing record 17 of set 12|kroya
# Processing record 18 of set 12|vao
# Processing record 19 of set 12|sambava
# Processing record 20 of set 12|rivera
# Processing record 21 of set 12|fare
# Processing record 22 of set 12|honningsvag
# Processing record 23 of set 12|linhares
# Processing record 24 of set 12|caravelas
# Processing record 25 of set 12|frontera
# Processing record 26 of set 12|launceston
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# create dataframe
weather_data = pd.DataFrame({
    'City': cityname,
    'Cloudiness': cloudiness,
    'Country': country,
    'Date': date,
    'Humidity': humidity,
    'Latitude': latitude,
    'Longitude': longitude,
    'Max Temperature': temperature_max,
    'Windspeed': windspeed
    
})
weather_data
weather_data.describe()
# Out:
#        Cloudiness          Date    Humidity    Latitude   Longitude  \
# count  576.000000  5.760000e+02  576.000000  576.000000  576.000000
# mean    55.428819  1.605655e+09   75.638889   18.688872   19.165868
# std     39.033477  7.047388e+01   19.024236   34.086356   90.564543
# min      0.000000  1.605655e+09   11.000000  -54.800000 -175.200000
# 25%     18.750000  1.605655e+09   68.000000   -8.950000  -58.117500
# 50%     66.500000  1.605655e+09   81.000000   20.880000   20.310000
# 75%     94.000000  1.605655e+09   89.000000   50.022500  102.272500
# max    100.000000  1.605655e+09  100.000000   78.220000  179.320000
#
#        Max Temperature   Windspeed
# count       576.000000  576.000000
# mean         55.727656    8.737569
# std          24.853623    6.095102
# min         -19.790000    0.380000
# 25%          39.200000    4.000000
# 50%          63.950000    7.755000
# 75%          75.835000   11.635000
# max          91.400000   44.400000

# %%
weather_data.to_csv("Output/weather_data.csv")

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(weather_data.iloc[:,5], weather_data.iloc[:,7], marker="d", facecolors="blue", edgecolors="red")

# Formatting the scatter plot
plt.title ("City Latitude\n VS \nMaximum Temperature", color='violet').set_fontsize(15) 
plt.xlabel("Latitude", color='blue').set_fontsize(10)
plt.ylabel("Max Temperature (F)", color='blue').set_fontsize(10)

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(weather_data.iloc[:,5], weather_data.iloc[:,4], marker="o", facecolors="blue", edgecolors="red")

# Formatting the scatter plot
plt.title ("City Latitude\n VS \nHumidity", color='violet').set_fontsize(15) 
plt.xlabel("Latitude", color='blue').set_fontsize(10)
plt.ylabel("Max Temperature (F)", color='blue').set_fontsize(10)

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_data.iloc[:,5], weather_data.iloc[:,1], marker="d", facecolors="blue", edgecolors="red")

# Formatting the scatter plot
plt.title ("City Latitude\n VS \nCloudiness", color='violet').set_fontsize(15) 
plt.xlabel("Latitude", color='blue').set_fontsize(10)
plt.ylabel("Max Temperature (F)", color='blue').set_fontsize(10)

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_data.iloc[:,5], weather_data.iloc[:,8], marker="o", facecolors="blue", edgecolors="red")

# Formatting the scatter plot
plt.title ("City Latitude\n VS \nMaximum Temperature", color='violet').set_fontsize(15) 
plt.xlabel("Latitude", color='blue').set_fontsize(10)
plt.ylabel("Max Temperature (F)", color='blue').set_fontsize(10)

# %% [markdown]
# ## Linear Regression

# %%
northern_hem_data = weather_data[(weather_data["Latitude"] >= 0)]
southern_hem_data = weather_data[(weather_data["Latitude"] < 0)]
northern_hem_data


#function for linear regression
def linear_regression(x,y):
   
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    print(f"r-squared : {round(rvalue,3)}")
    best_fit_plots = x * slope + intercept
    best_fit_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x, y, marker="d", facecolors="green", edgecolors="pink")
    plt.plot(x,best_fit_plots,linewidth = 1,color="purple")
    return best_fit_equation

# fuction for annotating
def annotate(best_fit_equation, a, b):
    plt.annotate(best_fit_equation,(a,b),fontsize=10)

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
xy = linear_regression(northern_hem_data['Latitude'], northern_hem_data['Max Temperature'])

# add regression formula
plt.annotate(xy,(10,20),color="black")

# Formatting 
plt.title ("Northern Hemisphere - Max Temperature (C) vs Latitude")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.grid()

# Save plot
plt.savefig("Output/Northern_Hemisphere_MaxTemp")
# Out:
# r-squared : -0.833

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
xy = linear_regression(southern_hem_data['Latitude'], southern_hem_data['Max Temperature'])

# add regression formula
plt.annotate(xy,(-20,50),color="black")

# Formatting 
plt.title ("Southern. Hemisphere - Max Temperature (C) vs Latitude")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.grid()

# Save plot
plt.savefig("Output/Northern_Hemisphere_MaxTemp")
# Out:
# r-squared : 0.687

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
xy = linear_regression(northern_hem_data['Latitude'], northern_hem_data['Humidity'])

# add regression formula
plt.annotate(xy,(50,20),color="black")

# Formatting 
plt.title ("Northern Hemisphere - Humidity (%) vs Latitude")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()

# Save plot
plt.savefig("Output/Northern_Hemisphere_Humidity")
# Out:
# r-squared : 0.237

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
xy = linear_regression(southern_hem_data['Latitude'], southern_hem_data['Humidity'])

# add regression formula
plt.annotate(xy,(-50,20),color="black")

# Formatting 
plt.title ("Southern Hemisphere - Humidity (%) vs Latitude")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()

# Save plot
plt.savefig("Output/Southern_Hemisphere_Humidity")
# Out:
# r-squared : 0.323

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
xy = linear_regression(northern_hem_data['Latitude'], northern_hem_data['Cloudiness'])

# add regression formula
plt.annotate(xy,(25,30),color="black")

# Formatting 
plt.title ("Northern Hemisphere - Cloudiness (%) vs Latitude")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()

# Save plot
plt.savefig("Output/Northern_Hemisphere_Cloudiness")
# Out:
# r-squared : 0.301

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
xy = linear_regression(southern_hem_data['Latitude'], southern_hem_data['Cloudiness'])

# add regression formula
plt.annotate(xy,(-55,50),color="black")

# Formatting 
plt.title ("Southern Hemisphere - Cloudiness (%) vs Latitude")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()

# Save plot
plt.savefig("Output/Southern_Hemisphere_Cloudiness")
# Out:
# r-squared : 0.098

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
xy = linear_regression(northern_hem_data['Latitude'], northern_hem_data['Windspeed'])

# add regression formula
plt.annotate(xy,(0,25),color="black")

# Formatting 
plt.title ("Northern Hemisphere - Windspeed (mp/h) vs Latitude")
plt.xlabel("Latitude")
plt.ylabel("Windspeed (mp/h)")
plt.grid()

# Save plot
plt.savefig("Output/Northern_Hemisphere_Windspeed")
# Out:
# r-squared : 0.303

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
xy = linear_regression(southern_hem_data['Latitude'], southern_hem_data['Windspeed'])

# add regression formula
plt.annotate(xy,(-30,30),color="black")

# Formatting 
plt.title ("Southern Hemisphere - Windspeed (mp/h) vs Latitude")
plt.xlabel("Latitude")
plt.ylabel("Windspeed (mp/h)")
plt.grid()

# Save plot
plt.savefig("Output/Southern_Hemisphere_Windspeed")
# Out:
# r-squared : -0.329
